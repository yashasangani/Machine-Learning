# %% [markdown]
# <a href="https://colab.research.google.com/github/yashasangani/Machine-Learning/blob/main/Multivariable_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multivariable regression

# %%
from sklearn import datasets
data = datasets.fetch_california_housing()

# %%
x = data.data
y = data.target

# %%
import pandas as pd
df = pd.DataFrame(x, columns=data.feature_names)
for i in df.columns:
  df[i+'**2'] = df[i]**2
  df[i+'**3'] = df[i]**3
x2=df.values
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedInc**2   MedInc**3  ...  AveBedrms**2  AveBedrms**3  \
# 0    -122.23  69.308955  577.010912  ...      1.048186      1.073143
# 1    -122.22  68.913242  572.076387  ...      0.944552      0.917991
# 2    -122.24  52.669855  382.246204  ...      1.152287      1.236918
# 3    -122.25  31.844578  179.702136  ...      1.151456      1.235581
# 4    -122.25  14.793254   56.897815  ...      1.168736      1.263499
#
#    Population**2  Population**3  AveOccup**2  AveOccup**3  Latitude**2  \
# 0       103684.0   3.338625e+07     6.530864    16.689986    1434.8944
# 1      5764801.0   1.384129e+10     4.451433     9.391819    1433.3796
# 2       246016.0   1.220239e+08     7.852660    22.005195    1432.6225
# 3       311364.0   1.737411e+08     6.492025    16.541323    1432.6225
# 4       319225.0   1.803621e+08     4.758799    10.381164    1432.6225
#
#     Latitude**3  Longitude**2  Longitude**3
# 0  54353.799872    14940.1729 -1.826137e+06
# 1  54267.751656    14937.7284 -1.825689e+06
# 2  54224.761625    14942.6176 -1.826586e+06
# 3  54224.761625    14945.0625 -1.827034e+06
# 4  54224.761625    14945.0625 -1.827034e+06
#
# [5 rows x 24 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
x2_train, x2_test, y2_train, y2_test = train_test_split(x2, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model2 = LinearRegression()

model.fit(x_train, y_train)
model2.fit(x2_train, y2_train)

y_pred = model.predict(x_test)
y_pred2 = model2.predict(x2_test)

# %%
training_score = model.score(x_train, y_train)
testing_score = model.score(x_test, y_test)

# after adding features
training_score2 = model2.score(x2_train, y2_train)
testing_score2 = model2.score(x2_test, y2_test)

# %%
print("training_score = ",training_score)
print("testing_score = ",testing_score)
print("training_score2 = ",training_score2)
print("testing_score2 = ",testing_score2)
# Out:
# training_score =  0.6125511913966952
# testing_score =  0.5757877060324524
# training_score2 =  0.6610356075962456
# testing_score2 =  -4.385556382210186
